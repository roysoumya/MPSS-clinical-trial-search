# %%
import pandas as pd
import pickle
from quickUmls.client import get_quickumls_client
import networkx as nx
from os.path import join

# %% [markdown]
# ### Get Concepts from Query

# %%
def getConceptsFromQuery(query):
    matcher = get_quickumls_client()
    concepts = matcher.match(query, best_match=True, ignore_syntax=False)
    concept = concepts[0][0]['cui']
    return concept

# %% [markdown]
# ### Read Query Data

# %%
query_df = pd.read_csv("../data/topics.csv")

# %%
query_df.head()
# Out:
#     disease  age   sex                                 gene
# 0  melanoma   64  male                         BRAF (V600E)
# 1  melanoma   54  male                         BRAF (V600K)
# 2  melanoma   80  male                         BRAF (V600R)
# 3  melanoma   38  male                         BRAF (K601E)
# 4  melanoma   57  male  BRAF (V600E), PTEN loss of function

# %% [markdown]
# ## Read All Disease Csv File

# %%
all_trials_df = pd.read_csv("AllDataOfSnapshotInCsvFormat.csv")

# %%
all_trials_df.head()
# Out:
#         nct_id                                        brief_title  \
# 0  NCT01762241   Xbox Kinect Training in Men With Prostate Cancer
# 1  NCT01762982  Patch Test of Benzalkonium Chloride Disinfecta...
# 2  NCT01762280  A Phase I Study of Famitinib Malate in Patient...
# 3  NCT01762072  Effect of Vitamin B12 and n-3 Polyunsaturated ...
# 4  NCT01762696  A Real-time, Contextual Intervention Using Mob...
#
#                                       official_title  \
# 0  Xbox Kinect Training in Men With Metastatic Pr...
# 1  A Single Centre, Examiner-blind Human Patch Te...
# 2  A Phase I Study of Famitinib Malate in Patient...
# 3                                                NaN
# 4  A Real-time, Contextual Intervention Using PDA...
#
#                                        brief_summary  \
# 0  The purpose of this study is to investigate th...
# 1  The aim of the study is to evaluate the irrita...
# 2  Famitinib is a novel oral multitargeted tyrosi...
# 3  Vitamin B12and n-3 polyunsaturated fatty acids...
# 4  The purpose of this study is to further develo...
#
#                                 detailed_description  \
# 0  Patients will be recruited from the outpatient...
# 1  Benzalkonium chloride is recognized as safe an...
# 2  1. To evaluate the safety and tolerability of ...
# 3                                                NaN
# 4  This study proposes a pilot randomized trial t...
#
#                                          eligibility          overall_status  \
# 0  Inclusion Criteria: - Prostate cancer requirin...  Active, not recruiting
# 1  Inclusion Criteria: 1. Consent: Demonstrates u...               Completed
# 2  Inclusion Criteria: - Histological confirmed a...          Unknown status
# 3  Inclusion Criteria: - reliability, regular eat...          Unknown status
# 4  Inclusion Criteria: - Male or female between t...               Completed
#
#    condition gender  minimum_age  maximum_age       mesh_term_list  \
# 0        NaN   Male         40.0         99.0  Prostatic Neoplasms
# 1        NaN    All         18.0         60.0                  NaN
# 2        NaN    All         18.0         65.0                  NaN
# 3        NaN    All         20.0         28.0                  NaN
# 4        NaN    All         15.0         24.0      Marijuana Abuse
#
#                                         keyword_list
# 0  Prostate cancer;Androgen deprivation therapy;E...
# 1                                                NaN
# 2             Famitinib;Advanced Solid tumor;Phase I
# 3         homocysteine-vitamin B12-fish oil-ferritin
# 4  marijuana;intervention;adolescent, young adult...

# %% [markdown]
# ## Read Pickle File

# %%
concepts_dictionary_brief_title = pickle.load(open("../data/brief_title.p", "rb"))
concepts_dictionary_brief_summary = pickle.load(open("../data/brief_summary.p", "rb"))

# %% [markdown]
# ## Get All Results for a given query

# %%
def getSexMinAgeMaxAgeFromTrial(rowTrial):
    try:
        trialSex = all_trials_df.iloc[rowTrial, 8].lower()
        # trialSex = dfTrials.values[rowTrial][8].lower()
    except:
        trialSex = "all"
    try:
        minAge = int(all_trials_df.iloc[rowTrial,9])
        # minAge = int(dfTrials.values[rowTrial][9])
    except:
        minAge = 0
    try:
        maxAge = int(all_trials_df.ilco[rowTrial, 10])
        # maxAge = int(dfTrials.values[rowTrial][10])
    except:
        maxAge = 100
    return trialSex, minAge, maxAge

# %% [markdown]
# ## Apply Page Rank And Save Result to csv file

# %%
def applyPagerank(nct_ids, query):
    
    G1 = nx.Graph()
    G2 = nx.Graph()
    
    i = 0
    for nct1 in nct_ids:
        j = 0
        try:
            iConceptsBriefTitle = set(concepts_dictionary_brief_title[nct1])
#             print(iConceptsBriefTitle)
        except:
            iConceptsBriefTitle = set()
        try:
            iConceptsBriefSummary = set(concepts_dictionary_brief_summary[nct1])
        except:
            iConceptsBriefSummary = set()
        try:
            iUnionTitleSummary = iConceptsBriefTitle.union(iConceptsBriefSummary)
        except:
            iUnionTitleSummary = set()
        
        for nct2 in nct_ids:
            try:
                jConceptsBriefTitle = set(concepts_dictionary_brief_title[nct2])
            except:
                jConceptsBriefTitle = set()
            
            try:
                jConceptsBriefSummary = set(concepts_dictionary_brief_summary[nct2])
            except:
                jConceptsBriefSummary = set()
            
            try:
                jUnionTitleSummary = jConceptsBriefTitle.union(jConceptsBriefSummary)
            except:
                jUnionTitleSummary = ()
            
            score1 = len(iConceptsBriefTitle.intersection(jConceptsBriefTitle))/min(len(iConceptsBriefTitle), len(jConceptsBriefTitle))
            score2 = len(iUnionTitleSummary.intersection(jUnionTitleSummary))/min(len(iUnionTitleSummary), len(jUnionTitleSummary))
            
            #             print(score)
            G1.add_edge(nct1, nct2, weight=score1)
            G2.add_edge(nct1, nct2, weight=score2)
            j += 1
        i += 1
    
    print(G1, G2)
    pr1 = nx.pagerank_numpy(G1, alpha=0.9)
    pr2 = nx.pagerank_numpy(G2, alpha=0.9)
    
    pageRankList1 = []
    pageRankList2 = []
    
    listOflist = []
    for key in pr1.keys():
        listRow = []
        listRow.append(key)
        listRow.append(all_trials_df.loc[all_trials_df['nct_id'] == key].values[0][1])
        pageRankScore1 = pr1[key]
        pageRankScore2 = pr2[key]
        listRow.append(pageRankScore1)
        listRow.append(pageRankScore2)
        listOflist.append(listRow)
    
    columns = ['nct_id', 'brief_title', 'page_rank_score_brief_title', 'page_rank_score_brief_title_summary_combined']
    df_ = pd.DataFrame(listOflist, columns=columns)
    df_.to_csv(join("../data/pageRank2QueriesOurMethod", str(row) + query + "_pageRank" + ".csv"), index=False)
#     print(df.brief_title_concepts_list)

# %%
for row in range(query_df.shape[0]):
    query = query_df.iloc[row][0]
    print(row, query)
    age = int(query_df.iloc[row][1])
    sex = query_df.iloc[row][2].strip().lower()
    concept = getConceptsFromQuery(query)
    print(age, sex, concept)
#     print(concept)
    
    count = 0
    nct_ids = []
    for rowTrial in range(all_trials_df.shape[0]):
        nct_id = all_trials_df.iloc[rowTrial, 0]
        trialSex, minAge, maxAge = getSexMinAgeMaxAgeFromTrial(rowTrial)
#         print(concepts_dictionary[nct_id]) 
        if (concept in concepts_dictionary_brief_title[nct_id]) and (trialSex=='all' or sex==trialSex) and (age>=minAge and age<=maxAge):
            count += 1
            nct_ids.append(nct_id)
#             print("Yes")
    print(count)
    applyPagerank(nct_ids, query)
# Out:
# 0 melanoma
# 64 male C0025202
# 909
#
# 1 melanoma
# 54 male C0025202
# 909
#
# 2 melanoma
# 80 male C0025202
# 909
#
# 3 melanoma
# 38 male C0025202
# 908
#
# 4 melanoma
# 57 male C0025202
# 909
#
# 5 melanoma
# 67 male C0025202
# 909
#
# 6 melanoma
# 61 male C0025202
# 909
#
# 7 melanoma
# 63 female C0025202
# 913
#
# 8 melanoma
# 34 female C0025202
# 912
#
# 9 melanoma
# 65 female C0025202
# 913
#
# 10 melanoma
# 56 female C0025202
# 913
#
# 11 melanoma
# 62 female C0025202
# 913
#
# 12 melanoma
# 39 female C0025202
# 912
#
# 13 melanoma
# 66 female C0025202
# 913
#
# 14 melanoma
# 70 male C0025202
# 909
#
# 15 melanoma
# 60 male C0025202
# 909
#
# 16 melanoma
# 72 male C0025202
# 909
#
# 17 melanoma
# 48 female C0025202
# 913
#
# 18 melanoma
# 73 male C0025202
# 909
#
# 19 melanoma
# 86 female C0025202
# 913
#
# 20 melanoma
# 49 male C0025202
# 909
#
# 21 melanoma
# 74 female C0025202
# 913
#
# 22 melanoma
# 68 male C0025202
# 909
#
# 23 melanoma
# 47 male C0025202
# 909
#
# 24 melanoma
# 69 female C0025202
# 913
#
# 25 colorectal cancer
# 49 male C0009402
# 1366
#
# 26 medullary thyroid carcinoma
# 45 female C0238462
# 36
#
# 27 neuroblastoma
# 4 female C0027819
# 152
#
# 28 esophageal cancer
# 67 male C0014859
# 3
#
# 29 lung cancer
# 71 female C0242379
# 1458
#
# 30 head and neck squamous cell carcinoma
# 64 male C0007137
# 272
#
# 31 leukemia
# 4 female C0023418
# 106
#
# 32 gastric cancer
# 60 female C0024623
# 582
#
# 33 sarcoma
# 78 female C1261473
# 225
#
# 34 breast cancer
# 73 female C0006142
# 3130
#
# 35 lung cancer
# 49 female C0242379
# 1408
#
# 36 non-small cell carcinoma
# 68 male C1266002
# 1
#
# 37 cholangiocarcinoma
# 50 male C0206698
# 77
#
# 38 anaplastic large cell lymphoma
# 18 male C0206180
# 21
#
# 39 breast cancer
# 56 female C0006142
# 3074
#
# 40 papillary thyroid carcinoma
# 46 female C0238463
# 21
#
# 41 glioblastoma
# 84 male C0017636
# 206
#
# 42 basal cell carcinoma
# 56 female C0007117
# 72
#
# 43 glioma
# 82 male C0017638
# 269
#
# 44 thyroid cancer
# 40 female C0007115
# 1
#
# 45 lung cancer
# 57 male C0242379
# 1420
#
# 46 prostate cancer
# 70 male C0376358
# 1907
#
# 47 adenoid cystic carcinoma
# 58 female C0010606
# 20
#
# 48 acute myeloid leukemia
# 1 male C0023467
# 136
#
# 49 acute myeloid leukemia
# 13 male C0023467
# 167

# %%
all_trials_df.loc[all_trials_df['nct_id'] == 'NCT01752257'].values[0][1]
# Out:
# 'EF5 in Melanoma Patients'
